# %%
import numpy as np
import tensorflow as tf
import gym
import mujoco_py

np.random.seed(2)
tf.set_random_seed(2)  # reproducible

# Superparameters
OUTPUT_GRAPH = False
MAX_EPISODE = 50000
DISPLAY_REWARD_THRESHOLD = -10  # renders environment if total episode reward is greater then this threshold
MAX_EP_STEPS = 200 # maximum time step in one episode
RENDER = False # rendering wastes time
GAMMA = 0.9     # reward discount in TD error
ALPHA = 2
LR_A = 0.0005    # learning rate for actor
LR_C = 0.0005    # learning rate for critic
# env = gym.make('MountainCarContinuous-v0')
env = gym.make('Pendulum-v0')
env.seed(1)  # reproducible

N_F = env.observation_space.shape[0]
action_res = [41]
N_A = action_res[0]
u = np.linspace(env.action_space.low[0], env.action_space.high[0], num=action_res[0])
action_map = u
# Out:
# [2018-06-06 15:21:21,520] Making new env: Pendulum-v0

# %%
class ExpReplay(object):
    def __init__(self, memory_size, state_dim, act_dim, batch_size):
        self.memory_size = memory_size
        self.batch_size = batch_size
        self.state_dim = state_dim
        self.act_dim = act_dim
        self.states = np.empty((self.memory_size, self.state_dim), dtype=np.float32)
        self.actions = np.empty((self.memory_size, 1), dtype=np.float32)
        self.rewards = np.empty(self.memory_size, dtype=np.float32)
        self.next_states = np.empty((self.memory_size, self.state_dim), dtype=np.float32)
        self.count = 0
        self.current = 0
    def fifo(self, state, action, reward, next_state):
        self.states[self.current] = state
        self.actions[self.current] = action
        self.rewards[self.current] = reward
        self.next_states[self.current] = next_state
        self.current = (self.current + 1) % self.memory_size
        self.count = self.count + 1
    def add_trajectory(self, states, actions, rewards, next_states):
        num = len(observes)
        for i in range(0, num):
            self.fifo(states[i], actions[i], rewards[i], next_states[i])
    def sampling(self):
        indexes = np.random.randint(min(self.count, self.memory_size), size=self.batch_size)
        states = self.states[indexes]
        actions = self.actions[indexes]
        rewards = self.rewards[indexes]
        next_states = self.next_states[indexes]
        states = states.reshape((-1, self.state_dim))
        actions = actions.reshape((-1, 1))
        rewards = rewards.reshape((-1, 1))
        next_states = next_states.reshape((-1, self.state_dim))
        return states, actions, rewards, next_states

# %%
class Memory(object):
    def __init__(self, memory_size, state_dim, act_dim):
        self.memory_size = memory_size
        self.state_dim = state_dim
        self.act_dim = act_dim
        self.states = np.empty((self.memory_size, self.state_dim), dtype=np.float32)
        self.actions = np.empty((self.memory_size, 1), dtype=np.float32)
        self.rewards = np.empty(self.memory_size, dtype=np.float32)
        self.next_states = np.empty((self.memory_size, self.state_dim), dtype=np.float32)
        self.count = 0
        self.current = 0
    def fifo(self, state, action, reward, next_state):
        self.states[self.current] = state
        self.actions[self.current] = action
        self.rewards[self.current] = reward
        self.next_states[self.current] = next_state
        self.current = (self.current + 1) % self.memory_size
        self.count = self.count + 1
    def add_trajectory(self, states, actions, rewards, next_states):
        num = len(observes)
        for i in range(0, num):
            self.fifo(states[i], actions[i], rewards[i], next_states[i])
    def sampling(self):
        randpermlist = np.random.permutation(self.count)
        states = self.states[randpermlist]
        actions = self.actions[randpermlist]
        rewards = self.rewards[randpermlist]
        next_states = self.next_states[randpermlist]
        states = states.reshape((-1, self.state_dim))
        actions = actions.reshape((-1, 1))
        rewards = rewards.reshape((-1, 1))
        next_states = next_states.reshape((-1, self.state_dim))
        return states, actions, rewards, next_states
    def empty_memory(self):
        self.states = np.empty((self.memory_size, self.state_dim), dtype=np.float32)
        self.actions = np.empty((self.memory_size, 1), dtype=np.float32)
        self.rewards = np.empty(self.memory_size, dtype=np.float32)
        self.next_states = np.empty((self.memory_size, self.state_dim), dtype=np.float32)
        self.count = 0
        self.current = 0

# %%
class Actor(object):
    def __init__(self, sess, n_features, n_actions, lr=0.0005):
        self.sess = sess

        self.s = tf.placeholder(tf.float32, (None, n_features), "state")
        self.a = tf.placeholder(tf.float32, (None, n_actions), "act")
        self.td_error = tf.placeholder(tf.float32, (None, 1), "td_error")  # TD_error]
        self.eps = 1
        self.eps_decay_rate = 0.9
        self.eps_min = 0

        with tf.variable_scope('Actor'):
            l1 = tf.layers.dense(
                inputs=self.s,
                units=64,    # number of hidden units
                activation=tf.nn.relu,
                kernel_initializer=tf.random_normal_initializer(0., .1),    # weights
                # bias_initializer=tf.constant_initializer(0.1),  # biases
                name='l1'
            )

            l2 = tf.layers.dense(
                inputs=l1,
                units=32,    # number of hidden units
                activation=tf.nn.relu,
                kernel_initializer=tf.random_normal_initializer(0., .1),    # weights
                # bias_initializer=tf.constant_initializer(0.1),  # biases
                name='l2'
            )
            
            self.acts_prob = tf.layers.dense(
                inputs=l2,
                units=n_actions,    # output units
                activation=tf.contrib.sparsemax.sparsemax,   # get action probabilities
                kernel_initializer=tf.random_normal_initializer(0., .1),  # weights
                # bias_initializer=tf.constant_initializer(0.1),  # biases
                name='acts_prob'
            )
        '''    
        with tf.variable_scope('exp_v'):
            log_prob = tf.log(tf.reduce_sum(
                tf.multiply(self.acts_prob, self.a), 1, keep_dims = True))
            self.loss = tf.reduce_mean(log_prob * self.td_error)  # advantage (TD_error) guided loss

        with tf.variable_scope('train'):
            self.train_op = tf.train.AdamOptimizer(lr).minimize(-self.loss)
        '''
        with tf.variable_scope('exp_v'):
            self.error = self.td_error + ALPHA*0.5*tf.reduce_sum(
                tf.multiply(self.acts_prob, self.acts_prob), 1, keep_dims=True) + ALPHA*0.5 - ALPHA*tf.reduce_sum(
                tf.multiply(self.acts_prob, self.a), 1, keep_dims = True)
            # TD error + ALPHA(0.5*pi^2 + 0.5 - pi)
            self.loss = tf.reduce_sum(tf.square(self.error))

        with tf.variable_scope('train'):
            self.train_op = tf.train.AdamOptimizer(lr).minimize(self.loss)  
            
    def learn(self, s, a, td):
        BATCH_SIZE = 200
        NITER = int(s.shape[0]/BATCH_SIZE)
        for i in range(0, NITER):
            feed_dict = {self.s: s[i*BATCH_SIZE:(i+1)*BATCH_SIZE], 
                         self.a: a[i*BATCH_SIZE:(i+1)*BATCH_SIZE], 
                         self.td_error: td[i*BATCH_SIZE:(i+1)*BATCH_SIZE]}
            _, loss = self.sess.run([self.train_op, self.loss], feed_dict)
        return 0

    def choose_action(self, s):
        s = s[np.newaxis, :]
        probs = self.sess.run(self.acts_prob, {self.s: s})   # get probabilities for all actions
        probs = probs.ravel()
        probs = np.ones(probs.shape[0]) * self.eps / probs.shape[0] + probs * (1. - self.eps)
        probs = probs/np.sum(probs)
        return np.random.choice(np.arange(probs.shape[0]), p=probs)   # return a int
    
    def update_policy(self):
        self.eps = np.max((self.eps*self.eps_decay_rate, self.eps_min))
        
    def print_prob(self, s):
        probs = self.sess.run(self.acts_prob, {self.s: s})   # get probabilities for all actions
        probs = probs.ravel()
        probs = np.ones(probs.shape[0]) * self.eps / probs.shape[0] + probs * (1. - self.eps)
        probs = probs/np.sum(probs)
        print(probs)
        return probs

# %%
class Critic(object):
    def __init__(self, sess, n_features, lr=0.01):
        self.sess = sess

        self.s = tf.placeholder(tf.float32, (None, n_features), "state")
        self.v_ = tf.placeholder(tf.float32, (None, 1), "v_next")
        self.r = tf.placeholder(tf.float32, (None, 1), 'r')

        with tf.variable_scope('Critic'):
            l1 = tf.layers.dense(
                inputs=self.s,
                units=32,  # number of hidden units
                activation=tf.nn.relu,  # None
                # have to be linear to make sure the convergence of actor.
                # But linear approximator seems hardly learns the correct Q.
                kernel_initializer=tf.random_normal_initializer(0., .1),  # weights
                # bias_initializer=tf.constant_initializer(0.1),  # biases
                name='l1'
            )
            
            l2 = tf.layers.dense(
                inputs=l1,
                units=16,  # number of hidden units
                activation=tf.nn.relu,  # None
                # have to be linear to make sure the convergence of actor.
                # But linear approximator seems hardly learns the correct Q.
                kernel_initializer=tf.random_normal_initializer(0., .1),  # weights
                # bias_initializer=tf.constant_initializer(0.1),  # biases
                name='l2'
            )

            self.v = tf.layers.dense(
                inputs=l2,
                units=1,  # output units
                activation=None,
                kernel_initializer=tf.random_normal_initializer(0., .1),  # weights
                # bias_initializer=tf.constant_initializer(0.1),  # biases
                name='V'
            )
            
        with tf.variable_scope('squared_TD_error'):
            self.td_error = self.r + GAMMA * self.v_ - self.v
            self.loss = tf.reduce_sum(tf.square(self.td_error))    # TD_error = (r+gamma*V_next) - V_eval
        with tf.variable_scope('train'):
            self.train_op = tf.train.AdamOptimizer(lr).minimize(self.loss)

    def learn(self, s, r, s_):
        BATCH_SIZE = 200
        NITER = int(s.shape[0]/BATCH_SIZE)
        for i in range(0, NITER):
            v_ = self.sess.run(self.v, {self.s: s_[i*BATCH_SIZE:(i+1)*BATCH_SIZE]})
            td_error, _ = self.sess.run([self.td_error, self.train_op],
                                              {self.s: s[i*BATCH_SIZE:(i+1)*BATCH_SIZE], self.v_: v_, 
                                               self.r: r[i*BATCH_SIZE:(i+1)*BATCH_SIZE]})
        return 0
    
    def get_error(self, s, r, s_):
        v_ = self.sess.run(self.v, {self.s: s_})
        td_error = self.sess.run(self.td_error,
                                          {self.s: s, self.v_: v_, self.r: r})
        return td_error

# %%
sess = tf.Session()

actor = Actor(sess, n_features=N_F, n_actions=N_A, lr=LR_A)
# critic = Critic(sess, n_features=N_F, lr=LR_C)
critic = Critic(sess, n_features=N_F, lr=LR_C)     # we need a good teacher, so the teacher should learn faster than the actor
MEMORY_SIZE = 10000
BATCH_SIZE = 1000
memory = Memory(MEMORY_SIZE, N_F, N_A)
# replay = ExpReplay(MEMORY_SIZE, N_F, N_A, BATCH_SIZE)
sess.run(tf.global_variables_initializer())

if OUTPUT_GRAPH:
    tf.summary.FileWriter("logs/", sess.graph)

for i_episode in range(MAX_EPISODE):
    s = env.reset()
    t = 0
    track_r = []
    while True:
        if i_episode % 5 == 0: RENDER = True
        if RENDER: env.render()

        a = actor.choose_action(s)
        s_, r, done, info = env.step([action_map[a]])

        track_r.append(r)
       
        #td_error = critic.learn(s, r, s_)  # gradient = grad[r + gamma * V(s_) - V(s)]
        #actor.learn(s, a, td_error)     # true_gradient = grad[logPi(s,a) * td_error]
        memory.fifo(s, a, r, s_)
        s = s_
        t += 1
        if done or t >= MAX_EP_STEPS: #done or
            RENDER = False
            ep_rs_sum = sum(track_r)
            if 'running_reward' not in globals():
                running_reward = ep_rs_sum
            else:
                running_reward = running_reward * 0.95 + ep_rs_sum * 0.05
            if running_reward > DISPLAY_REWARD_THRESHOLD: RENDER = True  # rendering
            print("episode:", i_episode, "  reward:", int(running_reward))
            break
        
    if (i_episode + 1)%5 == 0:
        states, actions, rewards, next_states = memory.sampling()
        mx_actions = np.zeros((actions.shape[0], N_A))
        for i in range(0, states.shape[0]):
            mx_actions[i, int(actions[i, 0])] = 1
        td_errors = critic.get_error(states, rewards, next_states)
        actor.learn(states, mx_actions, td_errors)
        critic.learn(states, rewards, next_states)
        actor.update_policy()
        memory.empty_memory()
# Out:
# ('episode:', 0, '  reward:', -1313)
# ('episode:', 1, '  reward:', -1321)
# ('episode:', 2, '  reward:', -1320)
# ('episode:', 3, '  reward:', -1334)
# ('episode:', 4, '  reward:', -1332)
# ('episode:', 5, '  reward:', -1338)
# ('episode:', 6, '  reward:', -1349)
# ('episode:', 7, '  reward:', -1360)
# ('episode:', 8, '  reward:', -1340)
# ('episode:', 9, '  reward:', -1336)
# ('episode:', 10, '  reward:', -1313)
# ('episode:', 11, '  reward:', -1308)
# ('episode:', 12, '  reward:', -1331)
# ('episode:', 13, '  reward:', -1336)
# ('episode:', 14, '  reward:', -1336)
# ('episode:', 15, '  reward:', -1354)
# ('episode:', 16, '  reward:', -1352)
# ('episode:', 17, '  reward:', -1341)
# ('episode:', 18, '  reward:', -1322)
# ('episode:', 19, '  reward:', -1334)
# ('episode:', 20, '  reward:', -1346)
# ('episode:', 21, '  reward:', -1345)
# ('episode:', 22, '  reward:', -1317)
# ('episode:', 23, '  reward:', -1333)
# ('episode:', 24, '  reward:', -1321)
# ('episode:', 25, '  reward:', -1324)
# ('episode:', 26, '  reward:', -1316)
# ('episode:', 27, '  reward:', -1316)
# ('episode:', 28, '  reward:', -1301)
# ('episode:', 29, '  reward:', -1289)
# ('episode:', 30, '  reward:', -1279)
# ('episode:', 31, '  reward:', -1288)
# ('episode:', 32, '  reward:', -1261)
# ('episode:', 33, '  reward:', -1247)
# ('episode:', 34, '  reward:', -1238)
# ('episode:', 35, '  reward:', -1250)
# ('episode:', 36, '  reward:', -1241)
# ('episode:', 37, '  reward:', -1229)
# ('episode:', 38, '  reward:', -1226)
# ('episode:', 39, '  reward:', -1226)
# ('episode:', 40, '  reward:', -1219)
# ('episode:', 41, '  reward:', -1246)
# ('episode:', 42, '  reward:', -1244)
# ('episode:', 43, '  reward:', -1242)
# ('episode:', 44, '  reward:', -1238)
# ('episode:', 45, '  reward:', -1263)
# ('episode:', 46, '  reward:', -1248)
# ('episode:', 47, '  reward:', -1262)
# ('episode:', 271, '  reward:', -1494)
# ('episode:', 272, '  reward:', -1479)
# ('episode:', 273, '  reward:', -1481)
# ('episode:', 274, '  reward:', -1479)
# ('episode:', 275, '  reward:', -1476)
# ('episode:', 276, '  reward:', -1479)
# ('episode:', 277, '  reward:', -1493)
# ('episode:', 278, '  reward:', -1488)
# ('episode:', 279, '  reward:', -1504)
# ('episode:', 280, '  reward:', -1521)
# ('episode:', 281, '  reward:', -1529)
# ('episode:', 282, '  reward:', -1533)
# ('episode:', 283, '  reward:', -1539)
# ('episode:', 284, '  reward:', -1547)
# ('episode:', 285, '  reward:', -1547)
# ('episode:', 286, '  reward:', -1545)
# ('episode:', 287, '  reward:', -1561)
# ('episode:', 288, '  reward:', -1556)
# ('episode:', 289, '  reward:', -1549)
# ('episode:', 290, '  reward:', -1553)
# ('episode:', 291, '  reward:', -1543)
# ('episode:', 292, '  reward:', -1545)
# ('episode:', 293, '  reward:', -1556)
# ('episode:', 294, '  reward:', -1547)
# ('episode:', 295, '  reward:', -1554)
# ('episode:', 296, '  reward:', -1557)
# ('episode:', 297, '  reward:', -1555)
# ('episode:', 298, '  reward:', -1535)
# ('episode:', 299, '  reward:', -1543)
# ('episode:', 300, '  reward:', -1543)
# ('episode:', 301, '  reward:', -1538)
# ('episode:', 302, '  reward:', -1542)
# ('episode:', 303, '  reward:', -1548)
# ('episode:', 304, '  reward:', -1560)
# ('episode:', 305, '  reward:', -1558)
# ('episode:', 306, '  reward:', -1551)
# ('episode:', 307, '  reward:', -1553)
# ('episode:', 308, '  reward:', -1563)
# ('episode:', 309, '  reward:', -1568)
# ('episode:', 310, '  reward:', -1575)
# ('episode:', 311, '  reward:', -1577)
# ('episode:', 312, '  reward:', -1587)
# ('episode:', 313, '  reward:', -1600)
# ('episode:', 314, '  reward:', -1595)
# ('episode:', 315, '  reward:', -1609)
# ('episode:', 316, '  reward:', -1614)
# ('episode:', 317, '  reward:', -1609)
# ('episode:', 318, '  reward:', -1619)
# ('episode:', 319, '  reward:', -1618)
# ('episode:', 320, '  reward:', -1612)
# ('episode:', 321, '  reward:', -1607)
# ('episode:', 322, '  reward:', -1610)
# ('episode:', 323, '  reward:', -1619)
# ('episode:', 324, '  reward:', -1614)
# ('episode:', 325, '  reward:', -1610)
# ('episode:', 326, '  reward:', -1602)
# ('episode:', 327, '  reward:', -1592)
# ('episode:', 328, '  reward:', -1588)
# ('episode:', 329, '  reward:', -1579)
# ('episode:', 330, '  reward:', -1577)
# ('episode:', 331, '  reward:', -1578)
# ('episode:', 332, '  reward:', -1582)
# ('episode:', 333, '  reward:', -1574)
# ('episode:', 334, '  reward:', -1585)
# ('episode:', 335, '  reward:', -1592)
# ('episode:', 336, '  reward:', -1598)
# ('episode:', 337, '  reward:', -1592)
# ('episode:', 338, '  reward:', -1582)
# ('episode:', 339, '  reward:', -1590)
# ('episode:', 340, '  reward:', -1600)
# ('episode:', 341, '  reward:', -1601)
# ('episode:', 342, '  reward:', -1595)
# ('episode:', 343, '  reward:', -1588)
# ('episode:', 344, '  reward:', -1590)
# ('episode:', 345, '  reward:', -1601)
# ('episode:', 495, '  reward:', -1700)
# ('episode:', 496, '  reward:', -1699)
# ('episode:', 497, '  reward:', -1700)
# ('episode:', 498, '  reward:', -1709)
# ('episode:', 499, '  reward:', -1713)
# ('episode:', 500, '  reward:', -1719)
# ('episode:', 501, '  reward:', -1714)
# ('episode:', 502, '  reward:', -1717)
# ('episode:', 503, '  reward:', -1719)
# ('episode:', 504, '  reward:', -1717)
# ('episode:', 505, '  reward:', -1704)
# ('episode:', 506, '  reward:', -1708)
# ('episode:', 507, '  reward:', -1705)
# ('episode:', 508, '  reward:', -1707)
# ('episode:', 509, '  reward:', -1706)
# ('episode:', 510, '  reward:', -1706)
# ('episode:', 511, '  reward:', -1710)
# ('episode:', 512, '  reward:', -1711)
# ('episode:', 513, '  reward:', -1717)
# ('episode:', 514, '  reward:', -1715)
# ('episode:', 515, '  reward:', -1714)
# ('episode:', 516, '  reward:', -1711)
# ('episode:', 517, '  reward:', -1719)
# ('episode:', 518, '  reward:', -1718)
# ('episode:', 519, '  reward:', -1723)
# ('episode:', 520, '  reward:', -1712)
# ('episode:', 521, '  reward:', -1715)
# ('episode:', 522, '  reward:', -1716)
# ('episode:', 523, '  reward:', -1716)
# ('episode:', 524, '  reward:', -1710)
# ('episode:', 525, '  reward:', -1714)
# ('episode:', 526, '  reward:', -1708)
# ('episode:', 527, '  reward:', -1693)
# ('episode:', 528, '  reward:', -1700)
# ('episode:', 529, '  reward:', -1704)
# ('episode:', 530, '  reward:', -1711)
# ('episode:', 531, '  reward:', -1718)
# ('episode:', 532, '  reward:', -1723)
# ('episode:', 533, '  reward:', -1723)
# ('episode:', 534, '  reward:', -1721)
# ('episode:', 535, '  reward:', -1724)
# ('episode:', 536, '  reward:', -1724)
# ('episode:', 537, '  reward:', -1723)
# ('episode:', 538, '  reward:', -1726)
# ('episode:', 539, '  reward:', -1724)
# ('episode:', 540, '  reward:', -1719)
# ('episode:', 541, '  reward:', -1723)
# ('episode:', 542, '  reward:', -1730)
# ('episode:', 543, '  reward:', -1733)
# ('episode:', 544, '  reward:', -1730)
# ('episode:', 545, '  reward:', -1730)
# ('episode:', 546, '  reward:', -1734)
# ('episode:', 547, '  reward:', -1729)
# ('episode:', 548, '  reward:', -1734)
# ('episode:', 549, '  reward:', -1732)
# ('episode:', 550, '  reward:', -1734)
# ('episode:', 551, '  reward:', -1736)
# ('episode:', 552, '  reward:', -1738)
# ('episode:', 553, '  reward:', -1733)
# ('episode:', 554, '  reward:', -1733)
# ('episode:', 555, '  reward:', -1736)
# ('episode:', 556, '  reward:', -1725)
# ('episode:', 557, '  reward:', -1731)
# ('episode:', 558, '  reward:', -1727)
# ('episode:', 559, '  reward:', -1727)
# ('episode:', 560, '  reward:', -1721)
# ('episode:', 561, '  reward:', -1715)
# ('episode:', 562, '  reward:', -1717)
# ('episode:', 563, '  reward:', -1718)
# ('episode:', 564, '  reward:', -1718)
# ('episode:', 565, '  reward:', -1717)
# ('episode:', 566, '  reward:', -1717)
# ('episode:', 567, '  reward:', -1722)
# ('episode:', 568, '  reward:', -1719)
# ('episode:', 644, '  reward:', -1709)
# ('episode:', 645, '  reward:', -1703)
# ('episode:', 646, '  reward:', -1701)
# ('episode:', 647, '  reward:', -1695)
# ('episode:', 648, '  reward:', -1699)
# ('episode:', 649, '  reward:', -1701)
# ('episode:', 650, '  reward:', -1705)
# ('episode:', 651, '  reward:', -1710)
# ('episode:', 652, '  reward:', -1710)
# ('episode:', 653, '  reward:', -1714)
# ('episode:', 654, '  reward:', -1715)
# ('episode:', 655, '  reward:', -1716)
# ('episode:', 656, '  reward:', -1712)
# ('episode:', 657, '  reward:', -1711)
# ('episode:', 658, '  reward:', -1712)
# ('episode:', 659, '  reward:', -1716)
# ('episode:', 660, '  reward:', -1718)
# ('episode:', 661, '  reward:', -1708)
# ('episode:', 662, '  reward:', -1712)
# ('episode:', 663, '  reward:', -1708)
# ('episode:', 664, '  reward:', -1704)
# ('episode:', 665, '  reward:', -1707)
# ('episode:', 666, '  reward:', -1706)
# ('episode:', 667, '  reward:', -1709)
# ('episode:', 668, '  reward:', -1712)
# ('episode:', 669, '  reward:', -1713)
# ('episode:', 670, '  reward:', -1707)
# ('episode:', 671, '  reward:', -1710)
# ('episode:', 672, '  reward:', -1709)
# ('episode:', 673, '  reward:', -1713)
# ('episode:', 674, '  reward:', -1716)
# ('episode:', 675, '  reward:', -1712)
# ('episode:', 676, '  reward:', -1697)
# ('episode:', 677, '  reward:', -1700)
# ('episode:', 678, '  reward:', -1703)
# ('episode:', 679, '  reward:', -1696)
# ('episode:', 680, '  reward:', -1698)
# ('episode:', 681, '  reward:', -1702)
# ('episode:', 682, '  reward:', -1705)
# ('episode:', 683, '  reward:', -1701)
# ('episode:', 684, '  reward:', -1702)
# ('episode:', 685, '  reward:', -1705)
# ('episode:', 686, '  reward:', -1710)
# ('episode:', 687, '  reward:', -1714)
# ('episode:', 688, '  reward:', -1718)
# ('episode:', 689, '  reward:', -1715)
# ('episode:', 690, '  reward:', -1717)
# ('episode:', 691, '  reward:', -1719)
# ('episode:', 692, '  reward:', -1714)
# ('episode:', 693, '  reward:', -1716)
# ('episode:', 694, '  reward:', -1719)
# ('episode:', 695, '  reward:', -1716)
# ('episode:', 696, '  reward:', -1718)
# ('episode:', 697, '  reward:', -1716)
# ('episode:', 698, '  reward:', -1717)
# ('episode:', 699, '  reward:', -1719)
# ('episode:', 700, '  reward:', -1712)
# ('episode:', 701, '  reward:', -1712)
# ('episode:', 702, '  reward:', -1708)
# ('episode:', 703, '  reward:', -1711)
# ('episode:', 704, '  reward:', -1706)
# ('episode:', 705, '  reward:', -1709)
# ('episode:', 706, '  reward:', -1706)
# ('episode:', 707, '  reward:', -1709)
# ('episode:', 708, '  reward:', -1710)
# ('episode:', 709, '  reward:', -1712)
# ('episode:', 710, '  reward:', -1715)
# ('episode:', 711, '  reward:', -1704)
# ('episode:', 712, '  reward:', -1703)
# ('episode:', 713, '  reward:', -1705)
# ('episode:', 714, '  reward:', -1699)
# ('episode:', 715, '  reward:', -1688)
# ('episode:', 716, '  reward:', -1691)
# ('episode:', 717, '  reward:', -1695)
# ('episode:', 718, '  reward:', -1699)
# ('episode:', 719, '  reward:', -1699)
# ('episode:', 720, '  reward:', -1699)
# ('episode:', 721, '  reward:', -1695)
# ('episode:', 722, '  reward:', -1699)
# ('episode:', 723, '  reward:', -1697)
# ('episode:', 724, '  reward:', -1698)
# ('episode:', 725, '  reward:', -1696)
# ('episode:', 726, '  reward:', -1692)
# ('episode:', 727, '  reward:', -1689)
# ('episode:', 728, '  reward:', -1691)
# ('episode:', 729, '  reward:', -1695)
# ('episode:', 730, '  reward:', -1695)
# ('episode:', 731, '  reward:', -1693)
# ('episode:', 732, '  reward:', -1693)
# ('episode:', 733, '  reward:', -1688)
# ('episode:', 734, '  reward:', -1690)
# ('episode:', 735, '  reward:', -1687)
# ('episode:', 736, '  reward:', -1691)
# ('episode:', 737, '  reward:', -1690)
# ('episode:', 738, '  reward:', -1676)
# ('episode:', 739, '  reward:', -1679)
# ('episode:', 740, '  reward:', -1680)
# ('episode:', 741, '  reward:', -1684)
# ('episode:', 742, '  reward:', -1684)
# ('episode:', 743, '  reward:', -1687)
# ('episode:', 744, '  reward:', -1685)
# ('episode:', 745, '  reward:', -1682)
# ('episode:', 746, '  reward:', -1680)
# ('episode:', 747, '  reward:', -1682)
# ('episode:', 748, '  reward:', -1677)
# ('episode:', 749, '  reward:', -1675)
# ('episode:', 750, '  reward:', -1679)
# ('episode:', 751, '  reward:', -1684)
# ('episode:', 752, '  reward:', -1683)
# ('episode:', 753, '  reward:', -1678)
# ('episode:', 754, '  reward:', -1683)
# ('episode:', 755, '  reward:', -1687)
# ('episode:', 756, '  reward:', -1684)
# ('episode:', 757, '  reward:', -1677)
# ('episode:', 758, '  reward:', -1680)
# ('episode:', 759, '  reward:', -1681)
# ('episode:', 760, '  reward:', -1681)
# ('episode:', 761, '  reward:', -1681)
# ('episode:', 762, '  reward:', -1682)
# ('episode:', 763, '  reward:', -1685)
# ('episode:', 764, '  reward:', -1685)
# ('episode:', 765, '  reward:', -1682)
# ('episode:', 766, '  reward:', -1684)
# ('episode:', 767, '  reward:', -1686)
# ('episode:', 768, '  reward:', -1684)
# ('episode:', 769, '  reward:', -1684)
# ('episode:', 770, '  reward:', -1684)
# ('episode:', 771, '  reward:', -1689)
# ('episode:', 772, '  reward:', -1690)
# ('episode:', 773, '  reward:', -1683)
# ('episode:', 774, '  reward:', -1678)
# ('episode:', 775, '  reward:', -1676)
# ('episode:', 776, '  reward:', -1674)
# ('episode:', 777, '  reward:', -1668)
# ('episode:', 778, '  reward:', -1666)
# ('episode:', 779, '  reward:', -1669)
# ('episode:', 780, '  reward:', -1672)
# ('episode:', 781, '  reward:', -1673)
# ('episode:', 782, '  reward:', -1671)
# ('episode:', 783, '  reward:', -1668)
# ('episode:', 784, '  reward:', -1666)
# ('episode:', 785, '  reward:', -1662)
# ('episode:', 786, '  reward:', -1661)
# ('episode:', 787, '  reward:', -1663)
# ('episode:', 788, '  reward:', -1654)
# ('episode:', 789, '  reward:', -1659)
# ('episode:', 790, '  reward:', -1661)
# ('episode:', 791, '  reward:', -1664)
# ('episode:', 792, '  reward:', -1656)
# ('episode:', 793, '  reward:', -1659)
# ('episode:', 794, '  reward:', -1662)
# ('episode:', 795, '  reward:', -1668)
# ('episode:', 796, '  reward:', -1666)
# ('episode:', 797, '  reward:', -1663)
# ('episode:', 798, '  reward:', -1660)
# ('episode:', 799, '  reward:', -1665)
# ('episode:', 800, '  reward:', -1667)
# ('episode:', 801, '  reward:', -1668)
# ('episode:', 802, '  reward:', -1662)
# ('episode:', 803, '  reward:', -1666)
# ('episode:', 804, '  reward:', -1661)
# ('episode:', 805, '  reward:', -1658)
# ('episode:', 806, '  reward:', -1648)
# ('episode:', 807, '  reward:', -1650)
# ('episode:', 808, '  reward:', -1654)
# ('episode:', 809, '  reward:', -1657)
# ('episode:', 810, '  reward:', -1661)
# ('episode:', 811, '  reward:', -1656)
# ('episode:', 812, '  reward:', -1648)
# ('episode:', 813, '  reward:', -1643)
# ('episode:', 814, '  reward:', -1648)
# ('episode:', 815, '  reward:', -1644)
# ('episode:', 816, '  reward:', -1645)
# ('episode:', 817, '  reward:', -1644)
# ('episode:', 818, '  reward:', -1647)
# ('episode:', 819, '  reward:', -1644)
# ('episode:', 820, '  reward:', -1645)
# ('episode:', 821, '  reward:', -1649)
# ('episode:', 822, '  reward:', -1653)
# ('episode:', 823, '  reward:', -1653)
# ('episode:', 824, '  reward:', -1645)
# ('episode:', 825, '  reward:', -1648)
# ('episode:', 826, '  reward:', -1646)
# ('episode:', 827, '  reward:', -1643)
# ('episode:', 828, '  reward:', -1648)
# ('episode:', 829, '  reward:', -1648)
# ('episode:', 830, '  reward:', -1650)
# ('episode:', 831, '  reward:', -1653)
# ('episode:', 832, '  reward:', -1639)
# ('episode:', 833, '  reward:', -1642)
# ('episode:', 834, '  reward:', -1643)
# ('episode:', 835, '  reward:', -1645)
# ('episode:', 836, '  reward:', -1642)
# ('episode:', 837, '  reward:', -1645)
# ('episode:', 838, '  reward:', -1649)
# ('episode:', 839, '  reward:', -1653)
# ('episode:', 840, '  reward:', -1655)
# ('episode:', 841, '  reward:', -1655)
# ('episode:', 842, '  reward:', -1655)
# ('episode:', 843, '  reward:', -1658)
# ('episode:', 844, '  reward:', -1653)
# ('episode:', 845, '  reward:', -1656)
# ('episode:', 846, '  reward:', -1653)
# ('episode:', 847, '  reward:', -1645)
# ('episode:', 848, '  reward:', -1647)
# ('episode:', 849, '  reward:', -1649)
# ('episode:', 850, '  reward:', -1648)
# ('episode:', 851, '  reward:', -1652)
# ('episode:', 852, '  reward:', -1652)
# ('episode:', 853, '  reward:', -1650)
# ('episode:', 854, '  reward:', -1651)
# ('episode:', 855, '  reward:', -1653)
# ('episode:', 856, '  reward:', -1655)
# ('episode:', 857, '  reward:', -1656)
# ('episode:', 858, '  reward:', -1655)
# ('episode:', 859, '  reward:', -1655)
# ('episode:', 860, '  reward:', -1656)
# ('episode:', 861, '  reward:', -1653)
# ('episode:', 862, '  reward:', -1647)
# ('episode:', 863, '  reward:', -1650)
# ('episode:', 864, '  reward:', -1653)
# ('episode:', 865, '  reward:', -1654)
# ('episode:', 866, '  reward:', -1655)
# ('episode:', 867, '  reward:', -1654)
# ('episode:', 868, '  reward:', -1656)
# ('episode:', 869, '  reward:', -1648)
# ('episode:', 870, '  reward:', -1644)
# ('episode:', 871, '  reward:', -1634)
# ('episode:', 872, '  reward:', -1636)
# ('episode:', 873, '  reward:', -1634)
# ('episode:', 874, '  reward:', -1636)
# ('episode:', 875, '  reward:', -1633)
# ('episode:', 876, '  reward:', -1636)
# ('episode:', 877, '  reward:', -1632)
# ('episode:', 878, '  reward:', -1633)
# ('episode:', 879, '  reward:', -1633)
# ('episode:', 880, '  reward:', -1634)
# ('episode:', 881, '  reward:', -1635)
# ('episode:', 882, '  reward:', -1635)
# ('episode:', 883, '  reward:', -1636)
# ('episode:', 884, '  reward:', -1638)
# ('episode:', 885, '  reward:', -1638)
# ('episode:', 886, '  reward:', -1639)
# ('episode:', 887, '  reward:', -1640)
# ('episode:', 888, '  reward:', -1642)
# ('episode:', 889, '  reward:', -1644)
# ('episode:', 890, '  reward:', -1643)
# ('episode:', 891, '  reward:', -1634)
# ('episode:', 892, '  reward:', -1636)
# ('episode:', 893, '  reward:', -1631)
# ('episode:', 894, '  reward:', -1632)
# ('episode:', 895, '  reward:', -1635)
# ('episode:', 896, '  reward:', -1635)
# ('episode:', 897, '  reward:', -1638)
# ('episode:', 898, '  reward:', -1635)
# ('episode:', 899, '  reward:', -1634)
# ('episode:', 900, '  reward:', -1636)
# ('episode:', 901, '  reward:', -1624)
# ('episode:', 902, '  reward:', -1627)
# ('episode:', 903, '  reward:', -1629)
# ('episode:', 904, '  reward:', -1619)
# ('episode:', 905, '  reward:', -1617)
# ('episode:', 906, '  reward:', -1616)
# ('episode:', 907, '  reward:', -1618)
# ('episode:', 908, '  reward:', -1618)
# ('episode:', 909, '  reward:', -1613)
# ('episode:', 910, '  reward:', -1615)
# ('episode:', 911, '  reward:', -1611)
# ('episode:', 912, '  reward:', -1613)
# ('episode:', 913, '  reward:', -1616)
# ('episode:', 914, '  reward:', -1614)
# ('episode:', 915, '  reward:', -1614)
# ('episode:', 916, '  reward:', -1617)
# ('episode:', 917, '  reward:', -1619)
# ('episode:', 918, '  reward:', -1622)
# ('episode:', 919, '  reward:', -1619)
# ('episode:', 920, '  reward:', -1620)
# ('episode:', 921, '  reward:', -1620)
# ('episode:', 922, '  reward:', -1619)
# ('episode:', 923, '  reward:', -1619)
# ('episode:', 924, '  reward:', -1621)
# ('episode:', 925, '  reward:', -1620)
# ('episode:', 926, '  reward:', -1621)
# ('episode:', 927, '  reward:', -1614)
# ('episode:', 928, '  reward:', -1611)
# ('episode:', 929, '  reward:', -1612)
# ('episode:', 930, '  reward:', -1607)
# ('episode:', 931, '  reward:', -1606)
# ('episode:', 932, '  reward:', -1609)
# ('episode:', 933, '  reward:', -1610)
# ('episode:', 934, '  reward:', -1608)
# ('episode:', 935, '  reward:', -1608)
# ('episode:', 936, '  reward:', -1608)
# ('episode:', 937, '  reward:', -1610)
# ('episode:', 938, '  reward:', -1609)
# ('episode:', 939, '  reward:', -1605)
# ('episode:', 940, '  reward:', -1604)
# ('episode:', 941, '  reward:', -1601)
# ('episode:', 942, '  reward:', -1601)
# ('episode:', 943, '  reward:', -1599)
# ('episode:', 944, '  reward:', -1600)
# ('episode:', 945, '  reward:', -1602)
# ('episode:', 946, '  reward:', -1601)
# ('episode:', 947, '  reward:', -1600)
# ('episode:', 948, '  reward:', -1602)
# ('episode:', 949, '  reward:', -1601)
# ('episode:', 950, '  reward:', -1594)
# ('episode:', 951, '  reward:', -1592)
# ('episode:', 952, '  reward:', -1581)
# ('episode:', 953, '  reward:', -1582)
# ('episode:', 954, '  reward:', -1582)
# ('episode:', 955, '  reward:', -1579)
# ('episode:', 956, '  reward:', -1556)
# ('episode:', 957, '  reward:', -1560)
# ('episode:', 958, '  reward:', -1562)
# ('episode:', 959, '  reward:', -1564)
# ('episode:', 960, '  reward:', -1566)
# ('episode:', 961, '  reward:', -1563)
# ('episode:', 962, '  reward:', -1563)
# ('episode:', 963, '  reward:', -1565)
# ('episode:', 964, '  reward:', -1564)
# ('episode:', 965, '  reward:', -1562)
# ('episode:', 966, '  reward:', -1565)
# ('episode:', 967, '  reward:', -1557)
# ('episode:', 968, '  reward:', -1550)
# ('episode:', 969, '  reward:', -1553)
# ('episode:', 970, '  reward:', -1553)
# ('episode:', 971, '  reward:', -1555)
# ('episode:', 972, '  reward:', -1558)
# ('episode:', 973, '  reward:', -1559)
# ('episode:', 974, '  reward:', -1559)
# ('episode:', 975, '  reward:', -1560)
# ('episode:', 976, '  reward:', -1563)
# ('episode:', 977, '  reward:', -1557)
# ('episode:', 978, '  reward:', -1554)
# ('episode:', 979, '  reward:', -1557)
# ('episode:', 980, '  reward:', -1554)
# ('episode:', 981, '  reward:', -1548)
# ('episode:', 982, '  reward:', -1546)
# ('episode:', 983, '  reward:', -1550)
# ('episode:', 984, '  reward:', -1551)
# ('episode:', 985, '  reward:', -1550)
# ('episode:', 986, '  reward:', -1541)
# ('episode:', 987, '  reward:', -1545)
# ('episode:', 988, '  reward:', -1547)
# ('episode:', 989, '  reward:', -1545)
# ('episode:', 990, '  reward:', -1542)
# ('episode:', 991, '  reward:', -1547)
# ('episode:', 992, '  reward:', -1551)
# ('episode:', 993, '  reward:', -1550)
# ('episode:', 994, '  reward:', -1550)
# ('episode:', 995, '  reward:', -1550)
# ('episode:', 996, '  reward:', -1552)
# ('episode:', 997, '  reward:', -1551)
# ('episode:', 998, '  reward:', -1552)
# ('episode:', 999, '  reward:', -1553)
# ('episode:', 1000, '  reward:', -1554)
# ('episode:', 1001, '  reward:', -1553)
# ('episode:', 1002, '  reward:', -1547)
# ('episode:', 1003, '  reward:', -1547)
# ('episode:', 1004, '  reward:', -1549)

# %%
for i_episode in range(0, 200):
    s = env.reset()
    t = 0
    track_r = []
    while True:
        env.render()

        a = actor.choose_action(s)
        s_, r, done, info = env.step(action_map[a, :])
        s = s_
        t += 1
        if t >= MAX_EP_STEPS: #done or
            ep_rs_sum = sum(track_r)

            if 'running_reward' not in globals():
                running_reward = ep_rs_sum
            else:
                running_reward = running_reward * 0.95 + ep_rs_sum * 0.05
            if running_reward > DISPLAY_REWARD_THRESHOLD: RENDER = True  # rendering
            print("episode:", i_episode, "  reward:", int(running_reward))
            break
